# %%
# %sql
-- Setup del catálogo y el esquema principal para los datos

CREATE CATALOG IF NOT EXISTS fire_risk_project;
USE CATALOG fire_risk_project;
CREATE SCHEMA IF NOT EXISTS 00_landing;
CREATE SCHEMA IF NOT EXISTS 01_bronze;
CREATE SCHEMA IF NOT EXISTS 02_silver;
CREATE SCHEMA IF NOT EXISTS 03_gold;
CREATE VOLUME IF NOT EXISTS fire_risk_project.00_landing.nasa_files;
CREATE VOLUME IF NOT EXISTS fire_risk_project.00_landing.meteo_files;
