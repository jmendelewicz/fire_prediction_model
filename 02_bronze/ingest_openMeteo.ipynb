# %%
# Librerías

from pyspark.sql.functions import current_timestamp, col
import logging

# %%
# %sql
CREATE VOLUME IF NOT EXISTS fire_risk_project.01_bronze.vol_procesamiento;

# %%
# Logger para avisar

logging.basicConfig(level=logging.INFO, format='%(asctime)s | %(levelname)s | %(name)s | %(message)s', datefmt='%H:%M:%S', force=True)
logger = logging.getLogger("ETL_BRONZE")

# Rutas 

PATH_SOURCE_CLIMA = "/Volumes/fire_risk_project/00_landing/meteo_files/open_meteo"
PATH_CHECKPOINT_CLIMA = "/Volumes/fire_risk_project/01_bronze/vol_procesamiento/opmeteo_files/checkpoint"
PATH_SCHEMA_CLIMA = "/Volumes/fire_risk_project/01_bronze/vol_procesamiento/opmeteo_files/schema_opmeteo"
TABLE_CLIMA = "fire_risk_project.01_bronze.bronze_open_meteo"

# %%
# %run ../00_setup_functions/common_functions

# %%
# Ejecución OpenMeteo
procesar_a_bronze(PATH_SOURCE_CLIMA, TABLE_CLIMA, PATH_CHECKPOINT_CLIMA, PATH_SCHEMA_CLIMA, "json")

# %%
# %sql

-- Comprobación de entradas

SELECT count(*) AS TOTAL_ENTRADAS FROM fire_risk_project.01_bronze.bronze_open_meteo LIMIT 10;

# %%
# Ver el schema de OpenMeteo, para ver cómo se cargó el json.

spark.table("fire_risk_project.01_bronze.bronze_open_meteo").printSchema()

# %%
# Finalizado el proceso ingesta para datos Open Meteo
